# %%
import sys
sys.path.insert(0, "../")
import utils.data_utils as utils

# %%
directory = "/Users/andy/Desktop/LREC"
utils.merge(directory)
# Out:
#      AvgFruitWeight (g) BatchId      Blem  Calyx size  Conveyor  Creases  Cup  \
# 0                   NaN     913       NaN      0.0000       0.0      NaN  901
# 1                   NaN     913       NaN      0.0000       0.0      NaN  561
# 2                   NaN     913       NaN      0.0000       0.0      NaN  562
# 3                   NaN     913       NaN      0.0000       0.0      NaN  574
# 4                   NaN     913       NaN      0.0000       0.0      NaN  579
# 5                   NaN     913       NaN      0.0000       0.0      NaN  580
# 6                   NaN     913       NaN      0.0000       0.0      NaN  593
# 7                   NaN     913       NaN      0.0000       0.0      NaN  652
# 8                   NaN     913       NaN      0.0000       0.0      NaN  654
# 9                   NaN     913       NaN      0.0000       0.0      NaN  655
# 10                  NaN     913       NaN      0.0000       0.0      NaN  656
# ...
